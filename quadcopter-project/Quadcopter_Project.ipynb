# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-5.87606262e+00 -6.53807382e+00  2.95225536e+01  2.41031028e-02
#   4.16491372e-02  0.00000000e+00]
# [-3.06655946 -2.55720632  6.20067429]
# [ 0.08030522 -0.05656089  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
init_pose = np.array([0., 0., 10., 0., 0., 0.])
task = Task(target_pos=target_pos, init_pose=init_pose)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b336a4ce0bc> in <module>()
#       5
#       6 num_episodes = 1000
# ----> 7 target_pos = np.array([0., 0., 10.])
#       8 task = Task(target_pos=target_pos)
#       9 agent = PolicySearch_Agent(task)
#
# NameError: name 'np' is not defined

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
import sys
import pandas as pd
import numpy as np
from agents.agent import DDPG
from hover import Task

num_episodes = 1000
init_pose = np.array([0., 0., 25., 0., 0., 0.])
target_pos = np.array([0., 0., 25.])
task = Task(init_pose=init_pose, target_pos=target_pos)
agent = DDPG(task)

best_score = -100000
results = {}

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    score = 0
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
        score += reward
        best_score = max(best_score , score)
        results[i_episode] = {'Episode': i_episode, 'Reward':score,'Action':action, 'Best_Score':best_score,
                                  'x':task.sim.pose[0], 'y':task.sim.pose[1],'z':task.sim.pose[2]}
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), (x = {:7.3f}, y = {:7.3f}, z = {:7.3f})".format(
                i_episode, score, best_score, task.sim.pose[0], task.sim.pose[1], task.sim.pose[2]), end="")
            break
    sys.stdout.flush()
# Out:
# Using TensorFlow backend.
# Episode = 1000, score = 955.030 (best = 3298.147), (x = -34.679, y =  -8.086, z = 148.408)))

# %%
results = pd.DataFrame.from_dict(results, orient='index')
results.tail(20)
# Out:
#       Episode      Reward                                             Action  \
# 981       981  942.478981  [899.3728420491933, 899.528399016642, 900.0155...
# 982       982  862.891269  [900.1525466550193, 900.1332558782319, 900.253...
# 983       983  964.541105  [900.4432312262103, 899.2629985471456, 899.623...
# 984       984  947.124015  [900.6147529429138, 899.8575543340494, 900.010...
# 985       985  947.183662  [900.0961459303008, 899.9137080741084, 900.262...
# 986       986  903.466285  [899.8575807847029, 900.7098533502875, 901.064...
# 987       987  968.764726  [900.0874282399202, 899.728018350936, 900.0785...
# 988       988  957.178768  [899.8268009907921, 899.4516538467469, 899.596...
# 989       989  962.497442  [900.4574640347838, 900.5989858442155, 899.820...
# 990       990  966.590299  [899.6443582912125, 899.6449270999697, 899.454...
# 991       991  867.332655  [899.7863131695401, 899.9397562422279, 899.427...
# 992       992  962.333012  [899.8353066825632, 899.6457976906814, 899.937...
# 993       993  971.905796  [900.3500137152886, 900.0482804548383, 899.710...
# 994       994  917.138714  [899.9783756869133, 900.333477303519, 899.9473...
# 995       995  938.524430  [900.7084346872424, 900.2188907875003, 900.389...
# 996       996  964.754900  [900.5766081076807, 900.1911655346929, 900.519...
# 997       997  957.338642  [899.6374256257973, 900.2691233668404, 899.824...
# 998       998  955.515441  [899.9836130330747, 899.8554475799563, 900.007...
# 999       999  959.697223  [900.0614011138557, 899.8097703295889, 899.783...
# 1000     1000  955.030104  [899.9152980219651, 900.3594498515888, 899.746...
#
#        Best_Score          x          y           z
# 981   3298.147447  29.071149 -22.986739  163.720742
# 982   3298.147447   7.162342  51.360470  300.000000
# 983   3298.147447 -10.470116   7.547072  153.628616
# 984   3298.147447 -53.992945  12.670779  134.258830
# 985   3298.147447   1.751574 -64.616253  132.449968
# 986   3298.147447  43.821519 -83.428612  203.632126
# 987   3298.147447   3.820657  -9.270331  152.735706
# 988   3298.147447  -1.918020  27.335818  150.787462
# 989   3298.147447  -8.174836 -17.282046  151.614942
# 990   3298.147447 -10.528583   7.685628  153.194712
# 991   3298.147447  37.307317  65.184389  300.000000
# 992   3298.147447  -9.033434  11.001833  153.971935
# 993   3298.147447   5.320999  -1.683320  153.361539
# 994   3298.147447 -43.619175  29.670596  214.350387
# 995   3298.147447 -68.718635 -16.260840  118.684317
# 996   3298.147447  13.754395   5.567429  152.488789
# 997   3298.147447   0.689131 -28.552337  152.602219
# 998   3298.147447  19.733342 -22.027876  151.294944
# 999   3298.147447  21.632238   2.269038  159.052210
# 1000  3298.147447 -34.678550  -8.086487  148.408028

# %%
print(f'Average final x position for last 100 episodes: {results["x"][-100:].mean()}'+str())
print(f'Average final y position for last 100 episodes: {results["y"][-100:].mean()}'+str())
print(f'Average final z position for last 100 episodes: {results["z"][-100:].mean()}'+str())
# Out:
# Average final x position for last 100 episodes: -2.1974836752911155
# Average final y position for last 100 episodes: -4.4678047821933005
# Average final z position for last 100 episodes: 163.50001678451244

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

plt.figure(figsize=(16,6))
plt.plot(results['Episode'], results['x'], label='x')
plt.plot(results['Episode'], results['y'], label='y')
plt.plot(results['Episode'], results['z'], label='z')
plt.legend()

# %%
# This visualization code was adapted from
# https://github.com/sozker/Train-a-Quadcopter-How-to-Fly/blob/master/Quadcopter_Project.ipynb

fig = plt.figure(figsize=(20,5))

ax1 = fig.add_subplot(1, 4, 1, projection='3d')
results250 = results[results['Episode']<=250]
ax1.plot3D(results250['x'], results250['y'], results250['z'], alpha=0.4, color='red')
ax1.set_title("Quadcopter end location: Episodes 1-250")
ax1.set_xlim([-100, 100])
ax1.set_ylim([-100, 100])
ax1.set_zlim([0, 200])

ax2 = fig.add_subplot(1, 4, 2, projection='3d')
results500 = results[(results['Episode']>250) & (results['Episode']<=500)]
ax2.plot3D(results500['x'], results500['y'], results500['z'], alpha=0.4, color='red')
ax2.set_title("Quadcopter end location: Episodes 251-500")
ax2.set_xlim([-100, 100])
ax2.set_ylim([-100, 100])
ax2.set_zlim([0, 200])

ax3 = fig.add_subplot(1, 4, 3, projection='3d')
results750 = results[(results['Episode']>500) & (results['Episode']<=750)]
ax3.plot3D(results750['x'], results750['y'], results750['z'], alpha=0.4, color='red')
ax3.set_title("Quadcopter end location: Episodes 501-750")
ax3.set_xlim([-100, 100])
ax3.set_ylim([-100, 100])
ax3.set_zlim([0, 200])

ax4 = fig.add_subplot(1, 4, 4, projection='3d')
results1000 = results[results['Episode']>750]
ax4.plot3D(results1000['x'], results1000['y'], results1000['z'], alpha=0.4, color='red')
ax4.set_title("Quadcopter end location: Episodes 751-100")
ax4.set_xlim([-100, 100])
ax4.set_ylim([-100, 100])
ax4.set_zlim([0, 200])
# Out:
# (0, 200)

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
plt.plot(results['Episode'], results['Reward'], label='Reward per Episode')
plt.legend()

# %% [markdown]
# ## Performance

# %%
# %load_ext autoreload
# %autoreload 2

# Modify the values below to give the quadcopter a different starting position.
runtime = 1000.                                  # time limit of the episode
init_pose = np.array([0., 0., 25., 0., 0., 0.])
target_pos = np.array([0., 0., 25.])
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime, target_pos)
done = False
performance = {}

# Run the simulation
state = agent.reset_episode()
total_reward = 0
i = 0

while True:
    i += 1
    rotor_speeds = agent.act(state)
    next_state, reward, done = task.step(rotor_speeds)
    to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
    performance[i] = {'Time': task.sim.time, 'x':task.sim.pose[0], 'y':task.sim.pose[1], 'z':task.sim.pose[2], 
                     'phi': task.sim.pose[3], 'theta': task.sim.pose[4], 'psi': task.sim.pose[5], 
                      'x_velocity': task.sim.v[0], 'y_velocity': task.sim.v[1], 
                      'z_velocity': task.sim.v[2], 'phi_velocity': task.sim.angular_v[0], 
                      'theta_velocity': task.sim.angular_v[1], 'psi_velocity': task.sim.angular_v[2], 
                      'rotor_speed1': rotor_speeds[0], 'rotor_speed2': rotor_speeds[1], 
                      'rotor_speed3': rotor_speeds[2], 'rotor_speed4': rotor_speeds[3]}
    total_reward += reward
    state = next_state
    if done:
        print(f"Total reward: {total_reward}")
        break
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Total reward: 841.0889292237744

# %%
performance = pd.DataFrame.from_dict(performance, orient='index')
performance
# Out:
#      Time             x             y           z       phi     theta  psi  \
# 1    0.06  1.248514e-07  3.107192e-07   25.069955  0.000085  6.283144  0.0
# 2    0.12  5.490227e-06  1.368327e-05   25.279037  0.000416  0.000078  0.0
# 3    0.18 -2.298630e-06  8.907551e-05   25.624742  0.000835  0.001093  0.0
# 4    0.24 -1.663650e-04  2.917100e-04   26.102817  0.000990  0.003129  0.0
# 5    0.30 -7.819115e-04  6.492563e-04   26.707423  0.000719  0.006000  0.0
# 6    0.36 -2.252861e-03  1.123980e-03   27.431441  6.282960  0.010220  0.0
# 7    0.42 -5.117926e-03  1.588441e-03   28.266817  6.281396  0.016238  0.0
# 8    0.48 -1.008121e-02  1.843840e-03   29.204925  6.279619  0.023675  0.0
# 9    0.54 -1.793741e-02  1.678404e-03   30.236834  6.277196  0.032050  0.0
# 10   0.60 -2.947638e-02  8.439649e-04   31.353518  6.273964  0.040987  0.0
# 11   0.66 -4.542135e-02 -9.544398e-04   32.546114  6.269865  0.050036  0.0
# 12   0.72 -6.638499e-02 -4.050812e-03   33.806157  6.264805  0.059500  0.0
# 13   0.78 -9.290000e-02 -8.813798e-03   35.125748  6.258382  0.070236  0.0
# 14   0.84 -1.255020e-01 -1.566686e-02   36.497633  6.250213  0.082307  0.0
# 15   0.90 -1.647464e-01 -2.510410e-02   37.915193  6.240500  0.095590  0.0
# 16   0.96 -2.112059e-01 -3.767037e-02   39.372484  6.229608  0.109867  0.0
# 17   1.02 -2.654655e-01 -5.393273e-02   40.864253  6.217532  0.125112  0.0
# 18   1.08 -3.281225e-01 -7.447640e-02   42.385839  6.203998  0.141260  0.0
# 19   1.14 -3.998012e-01 -9.992801e-02   43.933177  6.189052  0.158241  0.0
# 20   1.20 -4.811672e-01 -1.309662e-01   45.502779  6.173016  0.176272  0.0
# 21   1.26 -5.729491e-01 -1.683115e-01   47.091661  6.156301  0.195171  0.0
# 22   1.32 -6.759444e-01 -2.127144e-01   48.697285  6.138619  0.214386  0.0
# 23   1.38 -7.909880e-01 -2.649685e-01   50.317465  6.120478  0.233580  0.0
# 24   1.44 -9.189313e-01 -3.258947e-01   51.950299  6.102130  0.252834  0.0
# 25   1.50 -1.060654e+00 -3.963324e-01   53.594157  6.083440  0.272237  0.0
# 26   1.56 -1.217075e+00 -4.771480e-01   55.247632  6.064197  0.291575  0.0
# 27   1.62 -1.389128e+00 -5.692447e-01   56.909469  6.044195  0.309865  0.0
# 28   1.68 -1.577694e+00 -6.735650e-01   58.578496  6.023802  0.327063  0.0
# 29   1.74 -1.783582e+00 -7.910767e-01   60.253612  6.002952  0.343136  0.0
# 30   1.80 -2.007529e+00 -9.227736e-01   61.933788  5.982102  0.358258  0.0
# ..    ...           ...           ...         ...       ...       ...  ...
# 109  6.54 -8.835873e+01 -7.165253e+01  128.020862  3.989071  1.736365  0.0
# 110  6.60 -9.027630e+01 -7.255256e+01  127.611659  3.958622  1.767319  0.0
# 111  6.66 -9.221784e+01 -7.342019e+01  127.194436  3.928335  1.799823  0.0
# 112  6.72 -9.418354e+01 -7.425409e+01  126.772314  3.897132  1.834054  0.0
# 113  6.78 -9.617356e+01 -7.505292e+01  126.348724  3.864905  1.869784  0.0
# 114  6.84 -9.818804e+01 -7.581541e+01  125.927430  3.832292  1.906591  0.0
# 115  6.90 -1.002270e+02 -7.654037e+01  125.512461  3.799573  1.944051  0.0
# 116  6.96 -1.022902e+02 -7.722683e+01  125.108011  3.766525  1.981550  0.0
# 117  7.02 -1.043769e+02 -7.787413e+01  124.718324  3.733046  2.018484  0.0
# 118  7.08 -1.064862e+02 -7.848198e+01  124.347569  3.699761  2.054399  0.0
# 119  7.14 -1.086168e+02 -7.905053e+01  123.999714  3.667191  2.089259  0.0
# 120  7.20 -1.107671e+02 -7.958026e+01  123.678453  3.635740  2.123224  0.0
# 121  7.26 -1.129352e+02 -8.007201e+01  123.387183  3.605134  2.156263  0.0
# 122  7.32 -1.151190e+02 -8.052686e+01  123.128994  3.574965  2.187660  0.0
# 123  7.38 -1.173166e+02 -8.094621e+01  122.906568  3.545175  2.217623  0.0
# 124  7.44 -1.195256e+02 -8.133176e+01  122.722136  3.515523  2.246100  0.0
# 125  7.50 -1.217438e+02 -8.168545e+01  122.577493  3.485768  2.273292  0.0
# 126  7.56 -1.239688e+02 -8.200943e+01  122.474085  3.455864  2.299570  0.0
# 127  7.62 -1.261985e+02 -8.230598e+01  122.413077  3.425953  2.324539  0.0
# 128  7.68 -1.284308e+02 -8.257752e+01  122.395313  3.396109  2.348450  0.0
# 129  7.74 -1.306637e+02 -8.282656e+01  122.421343  3.366555  2.371308  0.0
# 130  7.80 -1.328953e+02 -8.305563e+01  122.491463  3.337226  2.393238  0.0
# 131  7.86 -1.351237e+02 -8.326727e+01  122.605717  3.308175  2.414383  0.0
# 132  7.92 -1.373474e+02 -8.346402e+01  122.763970  3.279207  2.435000  0.0
# 133  7.98 -1.395647e+02 -8.364837e+01  122.965975  3.250395  2.455017  0.0
# 134  8.04 -1.417741e+02 -8.382280e+01  123.211345  3.221959  2.474295  0.0
# 135  8.10 -1.439743e+02 -8.398972e+01  123.499527  3.193908  2.492864  0.0
# 136  8.16 -1.461639e+02 -8.415147e+01  123.829831  3.166221  2.510703  0.0
# 137  8.22 -1.483419e+02 -8.431032e+01  124.201437  3.138743  2.527936  0.0
# 138  8.28 -1.500000e+02 -8.446846e+01  124.613439  3.111437  2.544963  0.0
#
#      x_velocity  y_velocity  z_velocity  phi_velocity  theta_velocity  \
# 1      0.000013    0.000029    2.330190      0.004098       -0.002115
# 2      0.000163    0.000539    4.632933      0.008208        0.009142
# 3     -0.000761    0.002160    6.879919      0.004444        0.029125
# 4     -0.005460    0.004669    9.041473     -0.001422        0.042152
# 5     -0.016052    0.007167   11.094446     -0.011568        0.057326
# 6     -0.034291    0.008350   13.019583     -0.025798        0.088333
# 7     -0.062969    0.006601   14.804777     -0.026601        0.117236
# 8     -0.104464    0.001410   16.443244     -0.036468        0.134798
# 9     -0.159374   -0.007534   17.931346     -0.049619        0.147743
# 10    -0.227065   -0.021011   19.269623     -0.064100        0.151290
# 11    -0.305952   -0.039765   20.462741     -0.078517        0.149828
# 12    -0.394112   -0.064347   21.519149     -0.099633        0.170126
# 13    -0.491034   -0.095449   22.449184     -0.129125        0.192364
# 14    -0.597068   -0.134214   23.263898     -0.156335        0.214676
# 15    -0.712489   -0.181718   23.973363     -0.176309        0.232198
# 16    -0.837593   -0.238554   24.589937     -0.194803        0.247485
# 17    -0.972533   -0.304959   25.124215     -0.219117        0.264784
# 18    -1.117581   -0.381378   25.585349     -0.243273        0.276632
# 19    -1.273344   -0.468686   25.983964     -0.264522        0.293426
# 20    -1.440652   -0.567715   26.328760     -0.273405        0.311829
# 21    -1.620718   -0.678962   26.627707     -0.291680        0.320640
# 22    -1.814541   -0.803109   26.887767     -0.301513        0.319477
# 23    -2.022367   -0.940744   27.113643     -0.304110        0.320711
# 24    -2.244598   -1.092206   27.310215     -0.309366        0.321281
# 25    -2.481762   -1.257854   27.481600     -0.316169        0.327266
# 26    -2.734592   -1.438221   27.631135     -0.331841        0.309925
# 27    -3.002717   -1.634032   27.760627     -0.336586        0.291945
# 28    -3.284847   -1.845709   27.870960     -0.347419        0.273116
# 29    -3.579913   -2.073819   27.963716     -0.347645        0.254550
# 30    -3.886586   -2.318505   28.039650     -0.347228        0.246481
# ..          ...         ...         ...           ...             ...
# 109  -31.761279  -15.263382   -6.737448     -0.511362        0.506489
# 110  -32.158597  -14.734399   -6.895614     -0.500706        0.530038
# 111  -32.559891  -14.183331   -7.004105     -0.514484        0.558353
# 112  -32.963990  -13.609972   -7.058131     -0.534402        0.587622
# 113  -33.370263  -13.014724   -7.052231     -0.543196        0.607793
# 114  -33.779154  -12.398608   -6.981001     -0.544259        0.622842
# 115  -34.186000  -11.764328   -6.840919     -0.547507        0.627119
# 116  -34.584981  -11.116107   -6.630221     -0.558299        0.620366
# 117  -34.970413  -10.459823   -6.349025     -0.557386        0.603732
# 118  -35.336720   -9.802330   -5.999707     -0.549958        0.585632
# 119  -35.678724   -9.150342   -5.586375     -0.531500        0.569622
# 120  -35.991876   -8.509568   -5.113936     -0.512570        0.557886
# 121  -36.272423   -7.884644   -4.587308     -0.505594        0.529632
# 122  -36.518382   -7.280503   -4.012408     -0.497806        0.505993
# 123  -36.728327   -6.702102   -3.396227     -0.493989        0.481032
# 124  -36.899540   -6.154302   -2.746988     -0.494628        0.457057
# 125  -37.032967   -5.640664   -2.070847     -0.498612        0.444178
# 126  -37.129081   -5.164150   -1.373124     -0.497989        0.421161
# 127  -37.189662   -4.726887   -0.658447     -0.499581        0.403639
# 128  -37.215812   -4.330797    0.067651     -0.493381        0.385551
# 129  -37.209319   -3.976752    0.800682     -0.490999        0.369794
# 130  -37.172205   -3.665092    1.536717     -0.484778        0.355129
# 131  -37.105554   -3.395889    2.271363     -0.483014        0.346385
# 132  -37.012121   -3.168556    3.003067     -0.482401        0.337394
# 133  -36.893246   -2.982708    3.729445     -0.476133        0.324808
# 134  -36.750723   -2.837568    4.448198     -0.469879        0.313144
# 135  -36.585755   -2.732126    5.156202     -0.463204        0.300927
# 136  -36.400659   -2.665100    5.851938     -0.458166        0.288960
# 137  -36.196670   -2.635251    6.532672     -0.457533        0.283487
# 138  -35.976087   -2.641446    7.198439     -0.450666        0.284359
#
#      psi_velocity  rotor_speed1  rotor_speed2  rotor_speed3  rotor_speed4
# 1             0.0    900.014179    899.928623    899.885448    900.051254
# 2             0.0    899.549731    900.005385    899.891916    900.058157
# 3             0.0    899.591826    900.400367    900.304803    900.152352
# 4             0.0    899.618550    900.145749    900.313883    900.076441
# 5             0.0    899.671470    900.285840    900.273028    899.862469
# 6             0.0    899.226461    900.482821    900.224799    899.648911
# 7             0.0    899.312605    900.485798    899.966507    899.934244
# 8             0.0    899.557644    900.274045    900.517581    900.118445
# 9             0.0    899.798119    900.329441    900.595453    900.063233
# 10            0.0    900.009316    900.161422    900.463528    899.876957
# 11            0.0    899.921810    899.871402    900.372069    899.787397
# 12            0.0    899.402795    900.234512    900.507487    899.650499
# 13            0.0    899.456297    900.369848    900.744910    899.546896
# 14            0.0    899.527651    900.448133    900.920365    899.811790
# 15            0.0    899.527259    900.258108    900.815617    899.996523
# 16            0.0    899.718533    900.362520    900.908266    900.145996
# 17            0.0    899.873791    900.602985    901.003572    900.001881
# 18            0.0    899.903980    900.416530    900.850268    899.849718
# 19            0.0    899.662244    900.378889    900.964806    900.076675
# 20            0.0    899.707389    900.494238    900.619647    900.227570
# 21            0.0    900.028918    900.431919    900.695992    899.920375
# 22            0.0    900.376532    900.377426    900.447936    900.009637
# 23            0.0    900.098412    900.196268    900.287769    900.140181
# 24            0.0    900.057033    900.128332    900.218070    899.961764
# 25            0.0    899.906444    900.197815    900.229103    899.908326
# 26            0.0    900.398752    899.744902    900.430606    899.747553
# 27            0.0    900.575696    899.890529    899.971835    899.727231
# 28            0.0    900.300879    899.575712    900.138712    899.645210
# 29            0.0    900.314939    899.595258    899.860774    899.794394
# 30            0.0    899.977167    899.678711    900.025901    899.985568
# ..            ...           ...           ...           ...           ...
# 109           0.0    899.928766    900.365593    899.851665    900.067550
# 110           0.0    899.476182    900.561229    899.820649    900.124556
# 111           0.0    899.349028    900.640875    900.330673    899.646186
# 112           0.0    899.144631    900.491924    900.247933    899.306074
# 113           0.0    899.187719    900.182433    899.775613    899.275423
# 114           0.0    899.338361    900.137126    900.105666    899.915382
# 115           0.0    899.690217    900.059901    900.318689    900.038928
# 116           0.0    899.893861    899.817111    900.513835    899.925360
# 117           0.0    900.143069    899.659593    900.281865    900.163357
# 118           0.0    900.219596    899.665896    900.307753    900.454830
# 119           0.0    900.432854    899.953259    900.093121    900.693038
# 120           0.0    900.236332    899.921064    900.292480    900.921719
# 121           0.0    900.277224    899.282723    900.580500    900.733908
# 122           0.0    900.319912    899.497617    900.376749    900.566896
# 123           0.0    900.438511    899.550022    900.508741    900.541481
# 124           0.0    900.120349    899.259110    900.340674    900.194195
# 125           0.0    899.890334    899.468973    900.228011    899.945090
# 126           0.0    899.911284    899.071574    900.053412    899.955862
# 127           0.0    899.730746    899.104323    900.230394    900.043057
# 128           0.0    899.974218    899.317691    899.856308    899.985076
# 129           0.0    900.024936    899.455988    899.945191    899.921804
# 130           0.0    900.037163    899.506647    900.076463    900.210447
# 131           0.0    899.922572    899.627244    900.053893    900.009750
# 132           0.0    899.986623    899.678233    900.296462    900.206448
# 133           0.0    900.050702    899.593163    900.276303    900.416454
# 134           0.0    900.230100    899.805937    900.171042    900.313720
# 135           0.0    899.935791    899.485314    900.259404    900.422247
# 136           0.0    899.986881    899.542855    900.281637    900.381145
# 137           0.0    899.771045    899.587212    900.240198    900.163059
# 138           0.0    899.982884    900.055155    899.945862    900.122440
#
# [138 rows x 17 columns]

# %%
plt.plot(performance['Time'], performance['x'], label='x')
plt.plot(performance['Time'], performance['y'], label='y')
plt.plot(performance['Time'], performance['z'], label='z')
plt.legend()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**: I decided to teach the quadcopter how to hover at a set point.  I had it initialize and hover at position \[0, 0, 25\], but have found that the quadcopoter has a significant amount of trouble achieving this, and ultimately was only successful in keeping the helicopter from crashing at the end of an episode.  I am not sure of the reason for this, but it's possible that while the penalty for crashing must be high enough to disincentivize crashing, a high crashing penalty also incentivizes a general upward trajectory.  I attempted to counteract this by
#
# I attempted to modify the reward function in several ways: initially, by applying a non-linear function (`tanh`) to bound the reward, and by decreasing and therefore bounding the relative penalty for mispositioning (from 0.3 to 0.1, 0.01, etc.).  Decreasing and bounding the penalty, down to 0.001-0.005, seemed to have the best effect on performance, disincentiving crashing by making staying up in the air more rewarding.  Applying the non-linear function `tanh` did not have clear benefit at this point, and I discarded it.  To encourage hovering in place, I added high rewards for hitting the target precisely, moderately high rewards for staying in the general area of the target, and slight penalties for high velocities.
#
# `reward = 1 - 0.001*(abs(self.sim.pose[:3] - self.target_pos)).sum()`
#
# In the future, I will want to revise the reward function further, as I am sure that changing other critical aspects of it should make it more likely that the quadcopter will hover in place.  However, through numerous trials, I have not yet been able to achieve this.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**: I intially tried the default learning algorithm, attempting to modify only the reward function, which improved reward slightly, but did not teach the quadcopter how to fly.  I then used the learning algorithm recommended by Udacity (Deep Deterministic Policy Gradients; DDPG), initially with the default parameters and architecture.  Once I saw that this learning algorithm resulted in significant improvement in task-learning (given the right reward function, the quadcopter would eventually learn to hover, even if not at exactly the right position), I attempted to modify the architecture to either improve learning speed, improve performance, or decrease runtime (which had increased significantly, particularly when I increased layer sizes).
#
# In the end, I did not modify the hyperparameters.  The parameters were set as follows: $\tau$ = 0.01; $\gamma$ = 0.99.
#
# I modified the Neural Network architecture, as suggested, by increasing layer sizes (while at times decreasing the number of layers to increase speed), adding batch normalization to improve network performance and stability, and adding L2 regularizers to reduce overfitting.  In this case, I experimented, trading off performance vs. speed, until I arrived at a reasonable compromise.  The actor model had one dense hidden layer with 128 nodes, L2 regularization, batch normalization, and a ReLu activation function.  The critic model had two dense hiddern layers for the state and action pathways with 128 nodes each, L2 regularization, batch normalization, and a ReLu activation function.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**: This was a relatively difficult task to learn, and it took a lot of tweaking of the reward function and neural network architecture to reach the point where the quadcopter reliably learned to hover (and continue hovering) at or near the specified position.  (..........)

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**: The hardest part of this project was translating from the very complex, abstract, and rapidly presented information in the course to the task at hand.  Once I was able to map between the concepts I learned and the code I wanted to write, and started tweaking with the reward function and agent architecture and seeing results, it became easier.  However, I still do not feel that I fully grasp all of the issues at hand, and would need more time to get a good handle of how RL works.
#
# I found it interesting that occasionally, I was able to get the quadcopter to reliably hover for an extended number of episodes, but then would see it appear to un-learn this behavior, and reliably crash at the end of the episode.  I also found it interesting, although unsurprising, that it was more difficult to get the quadcopter to hover relatively close to the floor.
